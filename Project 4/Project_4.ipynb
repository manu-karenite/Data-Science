# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Data Science/16.07.2022/company_sales_data.csv")
df.head()
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Read Total profit of all months and show it using a line plot

# %%
sns.lineplot(x="month_number",y="total_profit",data=df,dashes=True).set(title="Monthly Profit")
# Out:
# [Text(0.5, 1.0, 'Monthly Profit')]

# %% [markdown]
# **Get total profit of all months and show line plot with the following Style properties**

# %% [markdown]
# Generated line plot must include following Style properties: –
#
# Line Style dotted and Line-color should be red.
# Show legend at the lower right location.
# X label name = Month Number.
# Y label name = Sold units number.
# Add a circle marker.
# Line marker color as read.
# Line width should be 3.

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(df["month_number"],df["total_profit"],linestyle="--",linewidth=3,color="#ff0000",marker=".",markerSize=18,markerEdgeColor="#000000",markerEdgeWidth=2,label="Monthly Profit")
axes.set_xlabel("Month Number")
axes.set_ylabel("Sold Units")
axes.set_xticks(df["month_number"])
axes.set_title("Company Sales data of last year")
axes.legend(loc=4)

# %% [markdown]
# Read all product sales data and show it  using a multiline plot
#
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,1.5,1.5])
axes.plot(df["month_number"],df["toothpaste"],linewidth=4,marker=".",markerSize=18,label="toothpase monthly sale")
axes.plot(df["month_number"],df["facecream"],linewidth=4,marker=".",markerSize=18,label="facecream monthly sale")
axes.plot(df["month_number"],df["facewash"],linewidth=4,marker=".",markerSize=18,label="facewash monthly sale")
axes.plot(df["month_number"],df["bathingsoap"],linewidth=4,marker=".",markerSize=18,label="bathingsoap monthly sale")
axes.plot(df["month_number"],df["shampoo"],linewidth=4,marker=".",markerSize=18,label="shampoo monthly sale")
axes.plot(df["month_number"],df["moisturizer"],linewidth=4,marker=".",markerSize=18,label="moisturizer monthly sale")
axes.set_xticks(df["month_number"])
axes.legend(loc="best")

# %% [markdown]
# Read toothpaste sales data of each month and show it using a scatter plot

# %%
sns.set_style("darkgrid")
sns.scatterplot(x="month_number",y="toothpaste",data=df).set(xlabel="Month Number",ylabel="Number of Units Sold",title="Monthly Sale of Toothpastes")
# Out:
# [Text(0, 0.5, 'Number of Units Sold'),
#  Text(0.5, 0, 'Month Number'),
#  Text(0.5, 1.0, 'Monthly Sale of Toothpastes')]

# %% [markdown]
# Read face cream and facewash product sales data and show it using the bar chart
#
# The bar chart should display the number of units sold per month for each product.
#
# Add a separate bar for each product in the same chart.

# %%
#not a scatter plot
#use matplotlib
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()

plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'Face Cream sales data', align='edge')
plt.bar([a+0.25 for a in monthList], faceWashSalesData, width= -0.25, label = 'Face Wash sales data', align='edge')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title(' Sales data')

plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Facewash and facecream sales data')
plt.show()

# %% [markdown]
# Read sales data of bathing soap of all months and show it using a bar chart.

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.bar(df["month_number"],df["bathingsoap"])
axes.set_xticks(df["month_number"])
axes.set_xlabel("Month Number")
axes.set_ylabel("Sale")
axes.set_title("Monthly Sale of Bathing Soap")
# Out:
# Text(0.5, 1.0, 'Monthly Sale of Bathing Soap')

# %%
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# Read the total profit of each month and show it using the histogram to see the most common profit ranges

# %%
#use matplotlib
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
axes.hist(df["total_profit"],[150000,175000,200000,225000,250000,300000,350000],label="Profit Data")
axes.set_xlabel("Profit Range in Dollar")
axes.set_ylabel("Annual Profit in Dollar")
axes.set_title("Profit Data")
axes.legend(loc=0)

# %% [markdown]
# Calculate total sale data for last year for each product and show it using a Pie chart

# %%
df
labels=["Facecream","Facewash","toothpaste","bathingsoap","shampoo","moisturizer"]
lis=[sum(df["facecream"]),sum(df["facewash"]),sum(df["toothpaste"]),sum(df["bathingsoap"]),sum(df["shampoo"]),sum(df["moisturizer"])]
plt.pie(lis,labels=labels,autopct='%.0f%%')
plt.title('Sales data')
plt.show()

# %% [markdown]
# Read Bathing soap facewash of all months and display it using the Subplot

# %%
# fig=plt.figure()
fig,axes=plt.subplots(nrows=2,ncols=1)

#handlig first graph
axes[0].plot(df["month_number"],df["bathingsoap"],color="#000000",markerSize=8,marker="o")
axes[0].set_xticks(df["month_number"])
axes[0].set_yticks([7500,10000,12500])
axes[0].set_title("Sales Data of Bathing Soap")


#handling 2nd graph
axes[1].plot(df["month_number"],df["facewash"],color="#ff0000",markerSize=8,marker="o")
axes[1].set_xticks(df["month_number"])
axes[1].set_yticks([1500,2000])
axes[1].set_title("Sales Data of Facewash")

plt.tight_layout()

# %% [markdown]
# Read all product sales data and show it using the stack plot

# %%
import pandas as pd
import matplotlib.pyplot as plt  


monthList  = df ['month_number'].tolist()

faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

plt.plot([],[],color='m', label='face Cream', linewidth=5)
plt.plot([],[],color='c', label='Face wash', linewidth=5)
plt.plot([],[],color='r', label='Tooth paste', linewidth=5)
plt.plot([],[],color='k', label='Bathing soap', linewidth=5)
plt.plot([],[],color='g', label='Shampoo', linewidth=5)
plt.plot([],[],color='y', label='Moisturizer', linewidth=5)

plt.stackplot(monthList, faceCremSalesData, faceWashSalesData, toothPasteSalesData, 
              bathingsoapSalesData, shampooSalesData, moisturizerSalesData, 
              colors=['m','c','r','k','g','y'])

plt.xlabel('Month Number')
plt.ylabel('Sales unints in Number')
plt.title('Alll product sales data using stack plot')
plt.legend(loc='upper left')
plt.show()
